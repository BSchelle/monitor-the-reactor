# %%
import sys
sys.path.append('..')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from interface.load_data import (
    load_data_fault_free_test,
    load_data_fault_free_train,
    load_data_faulty_test,
    load_data_faulty_train,
    load_data_fault_free_test_select

)
from sklearn.feature_selection import mutual_info_classif
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[88], line 7
#       5 import seaborn as sns
#       6 import numpy as np
# ----> 7 from interface.load_data import (
#       8     load_data_fault_free_test,
#       9     load_data_fault_free_train,
#      10     load_data_faulty_test,
#      11     load_data_faulty_train,
#      12     load_data_fault_free_test_select
#      13
#      14 )
#      15 from sklearn.feature_selection import mutual_info_classif
#
# ImportError: cannot import name 'load_data_fault_free_test_select' from 'interface.load_data' (/Users/titouan/code/project-lewagon/monitor-the-reactor/notebooks/../interface/load_data.py)

# %%
fault_free_test = load_data_fault_free_test()
fault_free_train = load_data_fault_free_train()
faulty_test = load_data_faulty_test()
faulty_train = load_data_faulty_train()

# %%
faulty_train.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %%
sns.heatmap(faulty_train.iloc[2500:3000].corr())
# Out:
# <Axes: >

# %%
to_keep_6 = faulty_train.drop(columns=['faultNumber', 'simulationRun', 'sample']).iloc[2500:3000].corr()

# %%
mask_6 = (to_keep_6 >= 0.3) & (to_keep_6 <= 0.8)

# %%
to_keep_18 = faulty_train.drop(columns=['faultNumber', 'simulationRun', 'sample']).iloc[8500:9000].corr()

# %%
mask_18 = (to_keep_18 >= 0.3) & (to_keep_18 <= 0.8)

# %%
to_keep_7 = faulty_train.drop(columns=['faultNumber', 'simulationRun', 'sample']).iloc[3000:3500].corr()

# %%
mask_7 = (to_keep_7 >= 0.3) & (to_keep_7 <= 0.8)

# %%
to_keep_13 = faulty_train.drop(columns=['faultNumber', 'simulationRun', 'sample']).iloc[6000:6500].corr()

# %%
mask_13 = (to_keep_13 >= 0.3) & (to_keep_13 <= 0.8)

# %%
X_6 = faulty_train.drop(columns=['simulationRun', 'sample']).iloc[2500:2999]
y_6 = faulty_train.faultNumber.iloc[2500:2999]

# %%
# Out:
# array([4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 1.00200401e-03, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16, 4.44089210e-16, 4.44089210e-16, 4.44089210e-16,
#        4.44089210e-16])

# %%
((mask_6 == mask_18) == (mask_7 == mask_13)).sum().sort_values(ascending=False).index[0]
# Out:
# 'xmeas_5'

# %%
from interface.load_data import load_data_fault_free_test_select

load_data_fault_free_test_select()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 from interface.load_data import load_data_fault_free_test_select
#       3 load_data_fault_free_test_select()
#
# ImportError: cannot import name 'load_data_fault_free_test_select' from 'interface.load_data' (/Users/titouan/code/project-lewagon/monitor-the-reactor/notebooks/../interface/load_data.py)
