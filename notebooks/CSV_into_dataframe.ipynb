# %% [markdown]
# # Chargement et séparation des données en dataframes

# %% [markdown]
# 1. Creer un dossier "data"
# 2. Remplacer les url avec vos propres chemins
# 3. Charger et transformer les données en dataframes

# %%
url_Faulty_train = '/Users/titouan/code/project-lewagon/monitor-the-reactor/notebooks/data/TEP_Faulty_Training.csv'
url_Faulty_test = '/Users/titouan/code/project-lewagon/monitor-the-reactor/notebooks/data/TEP_Faulty_Testing.csv'

url_FaultFree_train = '/Users/titouan/code/project-lewagon/monitor-the-reactor/notebooks/data/TEP_FaultFree_Training.csv'
url_FaultFree_test = '/Users/titouan/code/project-lewagon/monitor-the-reactor/notebooks/data/TEP_FaultFree_Testing.csv'

# %%
url_Faulty_train = '/home/bapt/code/Monitor-the-Reactor/csv/TEP_Faulty_Training.csv'
url_Faulty_test = '/home/bapt/code/Monitor-the-Reactor/csv/TEP_Faulty_Testing.csv'

url_FaultFree_train = '/home/bapt/code/Monitor-the-Reactor/csv/TEP_FaultFree_Training.csv'
url_FaultFree_test = '/home/bapt/code/Monitor-the-Reactor/csv/TEP_FaultFree_Testing.csv'

# %%
import pandas as pd

df_Faulty_train = pd.read_csv(url_Faulty_train)
# df_Faulty_test = pd.read_csv(url_Faulty_test)

# df_FaultFree_train = pd.read_csv(url_FaultFree_train)
# df_FaultFree_test = pd.read_csv(url_FaultFree_test)

# %%
df_Faulty_train.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_Faulty_train.shape
#
# AttributeError: 'TextFileReader' object has no attribute 'shape'

# %%
df_Faulty_test.shape
# Out:
# (9600000, 55)

# %%
df_FaultFree_train.shape
# Out:
# (250000, 55)

# %%
df_FaultFree_test.shape
# Out:
# (480000, 55)
