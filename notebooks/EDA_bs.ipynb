# %% [markdown]
# # EDA

# %% [markdown]
# Analyse du dataset : temps, run, fonctions, tableau des pannes

# %%
import sys
sys.path.append('..')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from Explo.load_df import get_df_from_csv

# %%
fault_free_test, fault_free_train, faulty_test, faulty_train = get_df_from_csv()

# %%
fault_free_test['simulationRun'].value_counts()
# Out:
# simulationRun
# 500    96
# 1      96
# 2      96
# 3      96
# 484    96
#        ..
# 9      96
# 8      96
# 7      96
# 6      96
# 5      96
# Name: count, Length: 500, dtype: int64

# %%
fault_free_train['simulationRun'].value_counts()
# Out:
# simulationRun
# 500    50
# 1      50
# 2      50
# 3      50
# 484    50
#        ..
# 9      50
# 8      50
# 7      50
# 6      50
# 5      50
# Name: count, Length: 500, dtype: int64

# %%
faulty_test['simulationRun'].value_counts()
# Out:
# simulationRun
# 500    1920
# 1      1920
# 2      1920
# 3      1920
# 484    1920
#        ...
# 9      1920
# 8      1920
# 7      1920
# 6      1920
# 5      1920
# Name: count, Length: 500, dtype: int64

# %%
faulty_train['simulationRun'].value_counts()
# Out:
# simulationRun
# 500    1000
# 1      1000
# 2      1000
# 3      1000
# 484    1000
#        ...
# 9      1000
# 8      1000
# 7      1000
# 6      1000
# 5      1000
# Name: count, Length: 500, dtype: int64

# %%
faulty_train.describe()
# Out:
#          faultNumber  simulationRun         sample        xmeas_1  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean       10.500000     250.500000     246.000000       0.261140
# std         5.766287     144.337423     144.308841       0.148957
# min         1.000000       1.000000       1.000000      -0.004067
# 25%         5.750000     125.750000     121.000000       0.218688
# 50%        10.500000     250.500000     246.000000       0.250880
# 75%        15.250000     375.250000     371.000000       0.282660
# max        20.000000     500.000000     491.000000       1.015900
#
#              xmeas_2        xmeas_3        xmeas_4        xmeas_5  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean     3663.768449    4505.569825       9.369152      26.900828
# std        43.034352     110.456632       0.362900       0.231622
# min      3357.200000    3577.600000       6.800300      25.557000
# ...

# %%
faulty_train.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %%
# Recupération de 3 runs : 1, 50, 200 et tracé des courbes types !
run_1 = faulty_train[(faulty_train['faultNumber']==1) & (faulty_train['simulationRun']==1)]
run_50 = faulty_train[(faulty_train['faultNumber']==1) & (faulty_train['simulationRun']==50)]
run_200 = faulty_train[(faulty_train['faultNumber']==1) & (faulty_train['simulationRun']==200)]

sns.lineplot(data=run_1, x='sample', y='xmv_9')
# Out:
# <Axes: xlabel='sample', ylabel='xmv_9'>

# %%
columns = list(faulty_train.columns)
y_s = columns[2:2+17]
plt.figure(figsize=(20,20))
plt.title('Fault 1, run 50')
run_50_5h = run_50.iloc[]
for i in range(1,17):
    plt.subplot(4, 4, i)
    sns.lineplot(data=run_50, x='sample', y=y_s[i])

plt.show()

# %%
sns.histplot(data=faulty_train, x='xmeas_2')
# Out:
# <Axes: xlabel='xmeas_2', ylabel='Count'>
