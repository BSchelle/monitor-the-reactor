# %%
from main import main

main()
# Out:
# --- 1. Configuration des Dossiers et Téléchargement ---
# Dossier créé: data/csv
# ❌ Le dossier data/csv est vide. Démarrage du téléchargement de 'afrniomelo/tep-csv'...
# Erreur lors du téléchargement Kaggle : 404 Client Error.
#
# Resource not found at URL: https://www.kaggle.com/datasets/afrniomelo/tep-csv/versions/1
# The server reported the following issues: Dataset not found
# Please make sure you specified the correct resource identifiers.
#
# ❌ Le script ne peut pas continuer sans le chemin du fichier CSV.
