# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      94     reply = _read_next_input_message()
#      95     if reply == _NOT_READY or not isinstance(reply, dict):
# ---> 96       time.sleep(0.025)
#      97       continue
#      98     if (
#
# KeyboardInterrupt:

# %%
import pandas as pd
import os
from typing import Iterator, Generator, List, Dict

# --- Constantes ---
CSV_FILE_PATH = None
CHUNK_SIZE = 100000  # Définir une taille de morceau (par exemple, 100 000 lignes)

def process_csv_by_chunks(path: str, chunk_size: int) -> List[pd.DataFrame] | None:
    """
    Charge un fichier CSV par morceaux, traite chaque morceau,
    et retourne une liste des DataFrames traités.

    Args:
        path (str): Le chemin vers le fichier CSV.
        chunk_size (int): Le nombre de lignes à lire à la fois.

    Returns:
        List[pd.DataFrame] | None: Une liste des DataFrames traités, ou None en cas d'erreur.
    """

    print(f"Tentative de chargement du fichier : {os.path.abspath(path)}")
    print(f"Chargement par morceaux de taille : {chunk_size} lignes.")

    if not os.path.exists(path):
        print(f"Erreur: Le fichier '{path}' est introuvable. Vérifiez le chemin d'accès.")
        return None

    processed_chunks = []
    chunk_index = 0

    try:
        # Créer un itérateur (TextFileReader) au lieu d'un DataFrame unique
        csv_iterator = pd.read_csv(path, chunksize=chunk_size)

        # Parcourir les morceaux générés par l'itérateur
        for chunk in csv_iterator:
            chunk_index += 1
            print(f"Traitement du morceau #{chunk_index} (taille: {len(chunk)} lignes)...")

            # 💡 --- Zone de Traitement des Données --- 💡
            # Ici, vous pouvez appliquer des opérations qui réduisent la taille du morceau,
            # comme le filtrage, l'agrégation ou le calcul de statistiques.

            # Exemple : Calculer la moyenne de toutes les colonnes et stocker
            # stats_df = chunk.mean().to_frame().T
            # processed_chunks.append(stats_df)

            # Exemple : Filtrer pour garder uniquement les lignes où 'col_A' > 10
            # filtered_chunk = chunk[chunk['col_A'] > 10]
            # processed_chunks.append(filtered_chunk)

            # --- Fin de la Zone de Traitement ---

            # Dans cet exemple, nous stockons le morceau complet filtré
            # Si vous avez 500Mo, vous DEVEZ faire un traitement pour réduire le morceau avant de l'ajouter
            # à 'processed_chunks', sinon vous resaturerez votre RAM.
            processed_chunks.append(chunk)


        print(f"\nChargement et traitement terminés. {chunk_index} morceaux traités.")

        # ⚠️ ATTENTION : La ligne suivante va CONSOLIDER TOUS les morceaux.
        # Si vous n'avez pas réduit la taille des morceaux, vous risquez une saturation RAM.
        # Si vous n'avez besoin que de statistiques, vous pouvez retourner processed_chunks directement.
        final_dataframe = pd.concat(processed_chunks, ignore_index=True)
        print(f"Taille du DataFrame final: {len(final_dataframe)} lignes.")
        return final_dataframe

    except Exception as e:
        print(f"Une erreur s'est produite lors du traitement du fichier CSV : {e}")
        return None

# %%
from google.colab import drive
drive.mount('/content')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-65800560.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      94     reply = _read_next_input_message()
#      95     if reply == _NOT_READY or not isinstance(reply, dict):
# ---> 96       time.sleep(0.025)
#      97       continue
#      98     if (
#
# KeyboardInterrupt:

# %%
FF_test = process_csv_by_chunks("/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Testing.csv",
                                chunk_size=CHUNK_SIZE)
# Out:
# Tentative de chargement du fichier : /content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Testing.csv
# Chargement par morceaux de taille : 100000 lignes.
# Erreur: Le fichier '/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Testing.csv' est introuvable. Vérifiez le chemin d'accès.

# %%
FF_test = process_csv_by_chunks('../raw_data/TEP_FaultFree_Testing.csv',
                                chunk_size=CHUNK_SIZE)
# Out:
# Tentative de chargement du fichier : /raw_data/TEP_FaultFree_Testing.csv
# Chargement par morceaux de taille : 100000 lignes.
# Erreur: Le fichier '../raw_data/TEP_FaultFree_Testing.csv' est introuvable. Vérifiez le chemin d'accès.

# %%
FF_test.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            0              1       1  0.25171   3672.4   4466.3   9.5122
# 1            0              1       2  0.25234   3642.2   4568.7   9.4145
# 2            0              1       3  0.24840   3643.1   4507.5   9.2901
# 3            0              1       4  0.25153   3628.3   4519.3   9.3347
# 4            0              1       5  0.21763   3655.8   4571.0   9.3087
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   27.057   42.473   2705.6  ...  54.494  24.527  59.710  22.357  40.149
# 1   26.999   42.586   2705.2  ...  53.269  24.465  60.466  22.413  39.956
# 2   26.927   42.278   2703.5  ...  54.000  24.860  60.642  22.199  40.074
# 3   26.999   42.330   2703.9  ...  53.860  24.553  61.908  21.981  40.141
# 4   26.901   42.402   2707.7  ...  53.307  21.775  61.891  22.412  37.696
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 0  40.074  47.955  47.300  42.100  15.345
# 1  36.651  45.038  47.502  40.553  16.063
# 2  41.868  44.553  47.479  41.341  20.452
# 3  40.066  48.048  47.440  40.780  17.123
# 4  38.295  44.678  47.530  41.089  18.681
#
# [5 rows x 55 columns]

# %%
df = FF_test
two_hour_mask = (df.loc[:,'sample']>=140) & (df.loc[:,'sample']<180)
FF_test_2h = df[two_hour_mask]
FF_test_2h
# Out:
#         faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
# 139               0              1     140  0.21894   3708.1   4520.0
# 140               0              1     141  0.32847   3669.8   4511.5
# 141               0              1     142  0.32584   3659.4   4510.5
# 142               0              1     143  0.26900   3701.0   4485.9
# 143               0              1     144  0.26980   3699.8   4477.6
# ...             ...            ...     ...      ...      ...      ...
# 479214            0            500     175  0.28574   3649.2   4507.5
# 479215            0            500     176  0.28362   3626.2   4487.7
# 479216            0            500     177  0.23878   3673.4   4454.6
# 479217            0            500     178  0.23929   3654.9   4456.2
# 479218            0            500     179  0.25549   3603.2   4511.4
#
#         xmeas_4  xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4  \
# 139      9.3634   26.851   42.553   2695.8  ...  53.936  21.322  60.641
# 140      9.3173   26.606   42.343   2696.9  ...  53.829  31.902  59.924
# 141      9.3382   26.780   42.624   2696.9  ...  53.841  32.161  61.024
# 142      9.4336   26.409   42.178   2696.0  ...  54.005  26.595  59.277
# 143      9.4473   27.031   42.393   2696.4  ...  54.103  26.516  61.277
# ...         ...      ...      ...      ...  ...     ...     ...     ...
# 479214   9.2500   26.800   42.229   2699.7  ...  52.905  27.889  62.153
# 479215   9.3004   26.952   42.298   2703.6  ...  53.143  28.098  63.467
# 479216   9.3937   26.950   42.553   2703.3  ...  52.870  23.544  60.977
# 479217   9.3055   26.710   42.364   2704.7  ...  52.850  23.494  61.623
# 479218   9.3089   26.854   42.392   2701.2  ...  54.514  24.833  61.040
#
#          xmv_5   xmv_6   xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 139     21.214  40.885  39.901  46.303  43.228  41.162  15.862
# 140     20.736  42.104  39.592  47.771  43.489  40.798  18.671
# 141     20.768  42.064  33.923  50.486  43.599  40.615  20.176
# 142     20.931  37.724  40.260  45.132  43.496  40.837  17.731
# 143     21.092  37.692  40.579  45.270  43.464  41.090  19.544
# ...        ...     ...     ...     ...     ...     ...     ...
# 479214  21.974  39.768  39.454  50.399  45.322  40.874  17.208
# 479215  22.243  39.851  37.979  47.343  45.193  40.945  17.228
# 479216  21.957  39.296  42.488  45.808  45.437  41.373  17.186
# 479217  22.139  39.197  40.903  46.753  45.492  41.502  16.852
# 479218  21.825  41.512  33.693  50.870  45.375  41.212  16.380
#
# [20000 rows x 55 columns]

# %%
FF_train = process_csv_by_chunks("/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Training.csv",
                                chunk_size=CHUNK_SIZE)
# Out:
# Tentative de chargement du fichier : /content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Training.csv
# Chargement par morceaux de taille : 100000 lignes.
# Traitement du morceau #1 (taille: 100000 lignes)...
# Traitement du morceau #2 (taille: 100000 lignes)...
# Traitement du morceau #3 (taille: 50000 lignes)...
#
# Chargement et traitement terminés. 3 morceaux traités.
# Taille du DataFrame final: 250000 lignes.

# %%
df = FF_train
two_hour_mask = df.loc[:,'sample']<40
FF_train_2h = df[two_hour_mask]
FF_train_2h
# Out:
#         faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
# 0                 0              1       1  0.25038   3674.0   4529.0
# 1                 0              1       2  0.25109   3659.4   4556.6
# 2                 0              1       3  0.25038   3660.3   4477.8
# 3                 0              1       4  0.24977   3661.3   4512.1
# 4                 0              1       5  0.29405   3679.0   4497.0
# ...             ...            ...     ...      ...      ...      ...
# 249534            0            500      35  0.25379   3673.3   4490.1
# 249535            0            500      36  0.25399   3628.8   4539.6
# 249536            0            500      37  0.21403   3667.9   4548.8
# 249537            0            500      38  0.21466   3690.4   4495.3
# 249538            0            500      39  0.24652   3685.8   4552.7
#
#         xmeas_4  xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4  \
# 0        9.2320   26.889   42.402   2704.3  ...  53.744  24.657  62.544
# 1        9.4264   26.721   42.576   2705.0  ...  53.414  24.588  59.259
# 2        9.4426   26.875   42.070   2706.2  ...  54.357  24.666  61.275
# 3        9.4776   26.758   42.063   2707.2  ...  53.946  24.725  59.856
# 4        9.3381   26.889   42.650   2705.1  ...  53.658  28.797  60.717
# ...         ...      ...      ...      ...  ...     ...     ...     ...
# 249534   9.4162   27.019   42.009   2708.7  ...  54.610  24.501  60.684
# 249535   9.3916   27.064   42.585   2709.8  ...  54.018  24.481  61.649
# 249536   9.3216   27.103   42.239   2710.3  ...  53.648  20.905  62.005
# 249537   9.4264   27.148   42.470   2707.0  ...  54.289  20.843  61.005
# 249538   9.3494   27.093   42.274   2706.7  ...  54.470  24.534  62.249
#
#          xmv_5   xmv_6   xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 0       22.137  39.935  42.323  47.757  47.510  41.258  18.447
# 1       22.084  40.176  38.554  43.692  47.427  41.359  17.194
# 2       22.380  40.244  38.990  46.699  47.468  41.199  20.530
# 3       22.277  40.257  38.072  47.541  47.658  41.643  18.089
# 4       21.947  39.144  41.955  47.645  47.346  41.507  18.461
# ...        ...     ...     ...     ...     ...     ...     ...
# 249534  22.838  37.994  41.755  46.042  47.012  41.127  16.648
# 249535  22.715  38.025  39.081  49.243  46.839  42.350  18.674
# 249536  22.855  41.598  37.011  43.438  46.952  41.435  17.428
# 249537  22.709  41.824  37.656  47.679  46.924  41.897  18.013
# 249538  22.683  38.928  39.589  44.889  46.641  39.667  17.838
#
# [19500 rows x 55 columns]

# %%
F_test = process_csv_by_chunks("/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_Faulty_Testing.csv",
                                chunk_size=CHUNK_SIZE)
# Out:
# Tentative de chargement du fichier : /content/drive/MyDrive/Colab Notebooks/raw_data/TEP_Faulty_Testing.csv
# Chargement par morceaux de taille : 100000 lignes.
# Traitement du morceau #1 (taille: 100000 lignes)...
# Traitement du morceau #2 (taille: 100000 lignes)...
# Traitement du morceau #3 (taille: 100000 lignes)...
# Traitement du morceau #4 (taille: 100000 lignes)...
# Traitement du morceau #5 (taille: 100000 lignes)...
# Traitement du morceau #6 (taille: 100000 lignes)...
# Traitement du morceau #7 (taille: 100000 lignes)...
# Traitement du morceau #8 (taille: 100000 lignes)...
# Traitement du morceau #9 (taille: 100000 lignes)...
# Traitement du morceau #10 (taille: 100000 lignes)...
# Traitement du morceau #11 (taille: 100000 lignes)...
# Traitement du morceau #12 (taille: 100000 lignes)...
# Traitement du morceau #13 (taille: 100000 lignes)...
# Traitement du morceau #14 (taille: 100000 lignes)...
# Traitement du morceau #15 (taille: 100000 lignes)...
# Traitement du morceau #16 (taille: 100000 lignes)...
# Traitement du morceau #17 (taille: 100000 lignes)...
# Traitement du morceau #18 (taille: 100000 lignes)...
# Traitement du morceau #19 (taille: 100000 lignes)...
# Traitement du morceau #20 (taille: 100000 lignes)...
# Traitement du morceau #21 (taille: 100000 lignes)...
# Traitement du morceau #22 (taille: 100000 lignes)...
# Traitement du morceau #23 (taille: 100000 lignes)...
# Traitement du morceau #24 (taille: 100000 lignes)...
# Traitement du morceau #25 (taille: 100000 lignes)...
# Traitement du morceau #26 (taille: 100000 lignes)...
# Traitement du morceau #27 (taille: 100000 lignes)...
# Traitement du morceau #28 (taille: 100000 lignes)...
# Traitement du morceau #29 (taille: 100000 lignes)...
# Traitement du morceau #30 (taille: 100000 lignes)...
# Traitement du morceau #31 (taille: 100000 lignes)...
# Traitement du morceau #32 (taille: 100000 lignes)...
# Traitement du morceau #33 (taille: 100000 lignes)...
# Traitement du morceau #34 (taille: 100000 lignes)...
# Traitement du morceau #35 (taille: 100000 lignes)...
# Traitement du morceau #36 (taille: 100000 lignes)...
# Traitement du morceau #37 (taille: 100000 lignes)...
# Traitement du morceau #38 (taille: 100000 lignes)...
# Traitement du morceau #39 (taille: 100000 lignes)...
# Traitement du morceau #40 (taille: 100000 lignes)...
# Traitement du morceau #41 (taille: 100000 lignes)...
# Traitement du morceau #42 (taille: 100000 lignes)...
# Traitement du morceau #43 (taille: 100000 lignes)...
# Traitement du morceau #44 (taille: 100000 lignes)...
# Traitement du morceau #45 (taille: 100000 lignes)...
# Traitement du morceau #46 (taille: 100000 lignes)...
# Traitement du morceau #47 (taille: 100000 lignes)...
# Traitement du morceau #48 (taille: 100000 lignes)...
# Traitement du morceau #49 (taille: 100000 lignes)...
# Traitement du morceau #50 (taille: 100000 lignes)...
# Traitement du morceau #51 (taille: 100000 lignes)...
# Traitement du morceau #52 (taille: 100000 lignes)...
# Traitement du morceau #53 (taille: 100000 lignes)...
# Traitement du morceau #54 (taille: 100000 lignes)...
# Traitement du morceau #55 (taille: 100000 lignes)...
# Traitement du morceau #56 (taille: 100000 lignes)...
# Traitement du morceau #57 (taille: 100000 lignes)...
# Traitement du morceau #58 (taille: 100000 lignes)...
# Traitement du morceau #59 (taille: 100000 lignes)...
# Traitement du morceau #60 (taille: 100000 lignes)...
# Traitement du morceau #61 (taille: 100000 lignes)...
# Traitement du morceau #62 (taille: 100000 lignes)...
# Traitement du morceau #63 (taille: 100000 lignes)...
# Traitement du morceau #64 (taille: 100000 lignes)...
# Traitement du morceau #65 (taille: 100000 lignes)...
# Traitement du morceau #66 (taille: 100000 lignes)...
# Traitement du morceau #67 (taille: 100000 lignes)...
# Traitement du morceau #68 (taille: 100000 lignes)...
# Traitement du morceau #69 (taille: 100000 lignes)...
# Traitement du morceau #70 (taille: 100000 lignes)...
# Traitement du morceau #71 (taille: 100000 lignes)...
# Traitement du morceau #72 (taille: 100000 lignes)...
# Traitement du morceau #73 (taille: 100000 lignes)...
# Traitement du morceau #74 (taille: 100000 lignes)...
# Traitement du morceau #75 (taille: 100000 lignes)...
# Traitement du morceau #76 (taille: 100000 lignes)...
# Traitement du morceau #77 (taille: 100000 lignes)...
# Traitement du morceau #78 (taille: 100000 lignes)...
# Traitement du morceau #79 (taille: 100000 lignes)...
# Traitement du morceau #80 (taille: 100000 lignes)...
# Traitement du morceau #81 (taille: 100000 lignes)...
# Traitement du morceau #82 (taille: 100000 lignes)...
# Traitement du morceau #83 (taille: 100000 lignes)...
# Traitement du morceau #84 (taille: 100000 lignes)...
# Traitement du morceau #85 (taille: 100000 lignes)...
# Traitement du morceau #86 (taille: 100000 lignes)...
# Traitement du morceau #87 (taille: 100000 lignes)...
# Traitement du morceau #88 (taille: 100000 lignes)...
# Traitement du morceau #89 (taille: 100000 lignes)...
# Traitement du morceau #90 (taille: 100000 lignes)...
# Traitement du morceau #91 (taille: 100000 lignes)...
# Traitement du morceau #92 (taille: 100000 lignes)...
# Traitement du morceau #93 (taille: 100000 lignes)...
# Traitement du morceau #94 (taille: 100000 lignes)...
# Traitement du morceau #95 (taille: 100000 lignes)...
# Traitement du morceau #96 (taille: 100000 lignes)...
#
# Chargement et traitement terminés. 96 morceaux traités.
# Taille du DataFrame final: 9600000 lignes.

# %%
df = F_test
two_hour_mask = (df.loc[:,'sample']>=140) & (df.loc[:,'sample']<180)
F_test_2h = df[two_hour_mask]
F_test_2h
# Out:
#          faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
# 0                  1              1       1  0.25171   3672.4   4466.3
# 1                  1              1       2  0.25234   3642.2   4568.7
# 2                  1              1       3  0.24840   3643.1   4507.5
# 3                  1              1       4  0.25153   3628.3   4519.3
# 4                  1              1       5  0.21763   3655.8   4571.0
# ...              ...            ...     ...      ...      ...      ...
# 9599074           20            500      35  0.26840   3682.1   4545.1
# 9599075           20            500      36  0.26615   3680.0   4569.8
# 9599076           20            500      37  0.22165   3717.8   4564.0
# 9599077           20            500      38  0.22011   3701.4   4599.8
# 9599078           20            500      39  0.22838   3691.3   4515.6
#
#          xmeas_4  xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4  \
# 0         9.5122   27.057   42.473   2705.6  ...  54.494  24.527  59.710
# 1         9.4145   26.999   42.586   2705.2  ...  53.269  24.465  60.466
# 2         9.2901   26.927   42.278   2703.5  ...  54.000  24.860  60.642
# 3         9.3347   26.999   42.330   2703.9  ...  53.860  24.553  61.908
# 4         9.3087   26.901   42.402   2707.7  ...  53.307  21.775  61.891
# ...          ...      ...      ...      ...  ...     ...     ...     ...
# 9599074   9.4087   27.040   42.389   2705.8  ...  54.360  26.278  60.106
# 9599075   9.3188   26.568   41.799   2705.0  ...  54.064  26.499  59.487
# 9599076   9.3475   26.991   42.454   2702.4  ...  54.674  21.529  59.768
# 9599077   9.4089   26.742   42.376   2701.9  ...  54.246  21.681  57.532
# 9599078   9.2593   26.980   42.269   2700.8  ...  54.385  21.987  63.106
#
#           xmv_5   xmv_6   xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 0        22.357  40.149  40.074  47.955  47.300  42.100  15.345
# 1        22.413  39.956  36.651  45.038  47.502  40.553  16.063
# 2        22.199  40.074  41.868  44.553  47.479  41.341  20.452
# 3        21.981  40.141  40.066  48.048  47.440  40.780  17.123
# 4        22.412  37.696  38.295  44.678  47.530  41.089  18.681
# ...         ...     ...     ...     ...     ...     ...     ...
# 9599074  22.122  38.829  36.137  47.124  48.040  41.025  17.688
# 9599075  21.893  38.798  39.373  47.468  48.366  41.686  20.098
# 9599076  22.168  39.194  36.705  47.258  48.363  41.073  17.805
# 9599077  22.198  39.437  36.371  42.541  48.473  41.031  18.983
# 9599078  22.171  42.021  34.430  47.603  48.645  41.127  17.201
#
# [390000 rows x 55 columns]

# %%
F_train = process_csv_by_chunks("/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_Faulty_Training.csv",
                                chunk_size=CHUNK_SIZE)
# Out:
# Tentative de chargement du fichier : /content/drive/MyDrive/Colab Notebooks/raw_data/TEP_Faulty_Training.csv
# Chargement par morceaux de taille : 100000 lignes.
# Traitement du morceau #1 (taille: 100000 lignes)...
# Traitement du morceau #2 (taille: 100000 lignes)...
# Traitement du morceau #3 (taille: 100000 lignes)...
# Traitement du morceau #4 (taille: 100000 lignes)...
# Traitement du morceau #5 (taille: 100000 lignes)...
# Traitement du morceau #6 (taille: 100000 lignes)...
# Traitement du morceau #7 (taille: 100000 lignes)...
# Traitement du morceau #8 (taille: 100000 lignes)...
# Traitement du morceau #9 (taille: 100000 lignes)...
# Traitement du morceau #10 (taille: 100000 lignes)...
# Traitement du morceau #11 (taille: 100000 lignes)...
# Traitement du morceau #12 (taille: 100000 lignes)...
# Traitement du morceau #13 (taille: 100000 lignes)...
# Traitement du morceau #14 (taille: 100000 lignes)...
# Traitement du morceau #15 (taille: 100000 lignes)...
# Traitement du morceau #16 (taille: 100000 lignes)...
# Traitement du morceau #17 (taille: 100000 lignes)...
# Traitement du morceau #18 (taille: 100000 lignes)...
# Traitement du morceau #19 (taille: 100000 lignes)...
# Traitement du morceau #20 (taille: 100000 lignes)...
# Traitement du morceau #21 (taille: 100000 lignes)...
# Traitement du morceau #22 (taille: 100000 lignes)...
# Traitement du morceau #23 (taille: 100000 lignes)...
# Traitement du morceau #24 (taille: 100000 lignes)...
# Traitement du morceau #25 (taille: 100000 lignes)...
# Traitement du morceau #26 (taille: 100000 lignes)...
# Traitement du morceau #27 (taille: 100000 lignes)...
# Traitement du morceau #28 (taille: 100000 lignes)...
# Traitement du morceau #29 (taille: 100000 lignes)...
# Traitement du morceau #30 (taille: 100000 lignes)...
# Traitement du morceau #31 (taille: 100000 lignes)...
# Traitement du morceau #32 (taille: 100000 lignes)...
# Traitement du morceau #33 (taille: 100000 lignes)...
# Traitement du morceau #34 (taille: 100000 lignes)...
# Traitement du morceau #35 (taille: 100000 lignes)...
# Traitement du morceau #36 (taille: 100000 lignes)...
# Traitement du morceau #37 (taille: 100000 lignes)...
# Traitement du morceau #38 (taille: 100000 lignes)...
# Traitement du morceau #39 (taille: 100000 lignes)...
# Traitement du morceau #40 (taille: 100000 lignes)...
# Traitement du morceau #41 (taille: 100000 lignes)...
# Traitement du morceau #42 (taille: 100000 lignes)...
# Traitement du morceau #43 (taille: 100000 lignes)...
# Traitement du morceau #44 (taille: 100000 lignes)...
# Traitement du morceau #45 (taille: 100000 lignes)...
# Traitement du morceau #46 (taille: 100000 lignes)...
# Traitement du morceau #47 (taille: 100000 lignes)...
# Traitement du morceau #48 (taille: 100000 lignes)...
# Traitement du morceau #49 (taille: 100000 lignes)...
# Traitement du morceau #50 (taille: 100000 lignes)...
#
# Chargement et traitement terminés. 50 morceaux traités.
# Taille du DataFrame final: 5000000 lignes.

# %%
df = F_train
two_hour_mask = df.loc[:,'sample']<40
F_train_2h = df[two_hour_mask]
F_train_2h
# Out:
#          faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
# 0                  1              1       1  0.25038   3674.0   4529.0
# 1                  1              1       2  0.25109   3659.4   4556.6
# 2                  1              1       3  0.25038   3660.3   4477.8
# 3                  1              1       4  0.24977   3661.3   4512.1
# 4                  1              1       5  0.29405   3679.0   4497.0
# ...              ...            ...     ...      ...      ...      ...
# 4999534           20            500      35  0.25317   3672.7   4491.3
# 4999535           20            500      36  0.25337   3628.3   4540.8
# 4999536           20            500      37  0.21316   3667.0   4550.6
# 4999537           20            500      38  0.21321   3700.0   4486.4
# 4999538           20            500      39  0.24533   3673.5   4571.4
#
#          xmeas_4  xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4  \
# 0         9.2320   26.889   42.402   2704.3  ...  53.744  24.657  62.544
# 1         9.4264   26.721   42.576   2705.0  ...  53.414  24.588  59.259
# 2         9.4426   26.875   42.070   2706.2  ...  54.357  24.666  61.275
# 3         9.4776   26.758   42.063   2707.2  ...  53.946  24.725  59.856
# 4         9.3381   26.889   42.650   2705.1  ...  53.658  28.797  60.717
# ...          ...      ...      ...      ...  ...     ...     ...     ...
# 4999534   9.3790   26.989   41.908   2711.9  ...  54.625  24.440  60.437
# 4999535   9.3464   27.028   42.462   2713.6  ...  54.032  24.420  61.349
# 4999536   9.2670   27.059   42.086   2714.8  ...  53.670  20.820  61.643
# 4999537   9.3483   27.173   42.682   2706.3  ...  54.439  20.815  60.973
# 4999538   9.3228   27.130   42.718   2689.5  ...  54.306  24.438  62.680
#
#           xmv_5   xmv_6   xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 0        22.137  39.935  42.323  47.757  47.510  41.258  18.447
# 1        22.084  40.176  38.554  43.692  47.427  41.359  17.194
# 2        22.380  40.244  38.990  46.699  47.468  41.199  20.530
# 3        22.277  40.257  38.072  47.541  47.658  41.643  18.089
# 4        21.947  39.144  41.955  47.645  47.346  41.507  18.461
# ...         ...     ...     ...     ...     ...     ...     ...
# 4999534  18.130  38.323  41.470  45.770  46.967  41.087  17.061
# 4999535  17.050  38.378  38.737  48.922  46.781  42.258  19.168
# 4999536  16.085  42.132  36.602  43.061  46.885  41.351  18.016
# 4999537  15.212  42.369  37.875  45.582  46.888  41.121  18.573
# 4999538  19.898  39.742  42.832  45.594  46.620  38.986  18.091
#
# [390000 rows x 55 columns]

# %%
df_list = [F_train_2h, F_test_2h, FF_train_2h, FF_test_2h]

F_train_2h.to_csv('/content/drive/MyDrive/Colab Notebooks/raw_data/F_train_2h.csv')

# %%
df_list = [F_train_2h, F_test_2h, FF_train_2h, FF_test_2h]

F_test_2h.to_csv('/content/drive/MyDrive/Colab Notebooks/raw_data/F_test_2h.csv')

# %%
df_list = [F_train_2h, F_test_2h, FF_train_2h, FF_test_2h]

FF_train_2h.to_csv('/content/drive/MyDrive/Colab Notebooks/raw_data/FF_train_2h.csv')

# %%
df_list = [F_train_2h, F_test_2h, FF_train_2h, FF_test_2h]

FF_test_2h.to_csv('/content/drive/MyDrive/Colab Notebooks/raw_data/FF_test_2h.csv')
