# %% [markdown]
# # Chercher a classifier si panne ou non !

# %%
import sys
sys.path.append('..')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from load_df import get_df_from_csv

# %%
fault_free_test, fault_free_train, faulty_test, faulty_train = get_df_from_csv()

# %%
fault_free_train['faultNumber'] = 0
fault_free_test['faultNumber'] = 0

# %%
fault_free_train['faultNumber'].value_counts()
fault_free_test['faultNumber'].value_counts()
# Out:
# faultNumber
# 0    48000
# Name: count, dtype: int64

# %%
faulty_train['faultNumber'] = 1
faulty_test['faultNumber'] = 1

faulty_train['faultNumber'].value_counts()
faulty_test['faultNumber'].value_counts()
# Out:
# faultNumber
# 1    826447
# Name: count, dtype: int64

# %%
fault_free_test.shape
# Out:
# (48000, 55)

# %%
fault_free_test.head()
# Out:
#              simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# faultNumber
# 0                        1       1  0.25171   3672.4   4466.3   9.5122
# 0                        1      11  0.30292   3663.3   4503.4   9.3600
# 0                        1      21  0.29717   3700.2   4486.9   9.4385
# 0                        1      31  0.25240   3685.4   4490.4   9.4279
# 0                        1      41  0.26068   3606.0   4466.1   9.2702
#
#              xmeas_5  xmeas_6  xmeas_7  xmeas_8  ...   xmv_3   xmv_4   xmv_5  \
# faultNumber                                      ...
# 0             27.057   42.473   2705.6   74.750  ...  24.527  59.710  22.357
# 0             27.259   42.377   2702.2   75.041  ...  30.049  60.412  22.072
# 0             26.654   42.247   2696.9   75.176  ...  29.109  59.895  21.414
# 0             27.338   42.206   2698.9   75.142  ...  24.469  60.829  22.033
# 0             27.281   41.913   2692.4   74.808  ...  25.786  63.168  22.002
#
# ...
