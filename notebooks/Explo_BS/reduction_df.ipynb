# %%
import pandas as pd

# %%
import os
# Affiche le contenu du dossier principal de votre Drive
os.listdir('/content/drive/MyDrive/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2750013138.py in <cell line: 0>()
#       1 import os
#       2 # Affiche le contenu du dossier principal de votre Drive
# ----> 3 os.listdir('/content/drive/MyDrive/')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/'

# %%
# Étape A: Vérifiez 'Colab Notebooks'
print(os.listdir('/content/drive/MyDrive/'))

# Étape B: S'il existe, vérifiez 'raw_data' à l'intérieur
# Assurez-vous que l'orthographe correspond exactement à ce qui est affiché par l'Étape A
print(os.listdir('/content/drive/MyDrive/Colab Notebooks/'))

# Étape C: Vérifiez le fichier final
# Encore une fois, assurez-vous que 'raw_data' est écrit correctement.
print(os.listdir('/content/drive/MyDrive/Colab Notebooks/raw_data/'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-92335882.py in <cell line: 0>()
#       1 # Étape A: Vérifiez 'Colab Notebooks'
# ----> 2 print(os.listdir('/content/drive/MyDrive/'))
#       3
#       4 # Étape B: S'il existe, vérifiez 'raw_data' à l'intérieur
#       5 # Assurez-vous que l'orthographe correspond exactement à ce qui est affiché par l'Étape A
#
# NameError: name 'os' is not defined

# %%
# !pip install google

# %%
import os
from google.colab import drive
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 from google.colab import drive
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 drive.mount("/content/drive", force_remount=True)
#
# NameError: name 'drive' is not defined

# %%
FF_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Testing.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2878168803.py in <cell line: 0>()
# ----> 1 FF_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/raw_data/TEP_FaultFree_Testing.csv")
#
# ...

# %%
from google.colab import files
import pandas as pd
import io

# Lance une boîte de dialogue pour sélectionner un fichier sur votre ordinateur
uploaded = files.upload()

# Récupère le nom du fichier téléchargé
file_name = list(uploaded.keys())[0]

# Lit le fichier en utilisant l'objet binaire téléchargé
df = pd.read_csv(io.BytesIO(uploaded[file_name]))

print(f"Fichier '{file_name}' chargé avec succès. Premières lignes du DataFrame :")
print(df.head())

# %%
df = pd.read_csv('/home/bapt/code/Monitor-the-Reactor/raw_data/TEP_FaultFree_Training.csv')
