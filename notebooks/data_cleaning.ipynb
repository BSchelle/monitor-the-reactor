# %% [markdown]
# # Data Cleaning

# %%
# Redefinir le chemin depuis le dossier interface pour utiliser les fonctions

import os
import sys

ROOT_DIR = os.path.abspath("..")
sys.path.append(ROOT_DIR)

# %%
# Importer toutes les focntion et librairies necessaire

from interface.load_data import (
    load_data_fault_free_train,
    load_data_fault_free_test,
    load_data_faulty_train,
    load_data_faulty_test
    )
import seaborn as sns

# %%
df_fault_free_train = load_data_fault_free_train()
df_fault_free_test = load_data_fault_free_test()

df_faulty_train = load_data_faulty_train()
df_faulty_test = load_data_faulty_test()

# %%
df_fault_free_train.shape
# Out:
# (250000, 55)

# %%
df_fault_free_test.shape
# Out:
# (480000, 55)

# %%
df_faulty_train.shape
# Out:
# (5000000, 55)

# %%
df_faulty_test.shape
# Out:
# (9600000, 55)

# %%
# Verify duplicates

print(df_fault_free_train.duplicated().sum())
print(df_fault_free_test.duplicated().sum())

print(df_faulty_train.duplicated().sum())
print(df_faulty_test.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
# Verify missing data

print(df_fault_free_train.isnull().sum().sum())
print(df_fault_free_test.isnull().sum().sum())
print(df_faulty_train.isnull().sum().sum())
print(df_faulty_test.isnull().sum().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
sns.histplot(df_faulty_train[['xmeas_1']].iloc[:10000])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df_faulty_train[['xmeas_2']].iloc[:10000])
# Out:
# <Axes: ylabel='Count'>

# %%
df_faulty_train.iloc[:10000]['simulationRun'].value_counts()
# Out:
# simulationRun
# 1    10000
# Name: count, dtype: int64

# %%
sns.histplot(df_faulty_train[['xmeas_3']].iloc[:10000])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df_faulty_train[['xmeas_4']].iloc[:10000])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df_faulty_train[['xmeas_5']].iloc[:10000])
# Out:
# <Axes: ylabel='Count'>
