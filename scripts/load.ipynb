# %%
from params import *
from get_data import get_data

df = get_data(col_to_keep=COLUMN_NAMES, sample_division=250)
# Out:
# /home/bapt/.pyenv/versions/monitor-the-reactor-model/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.head()
# Out:
#    faultNumber  simulationRun  sample
# 0            1              1     250
# 1            1              1     500
# 2            1              2     250
# 3            1              2     500
# 4            1              3     250
